# %%
import pandas as pd
df = pd.read_csv('wine.data.csv')

# %%
df.tail(5)
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 173           1.68        0.61                  0.52             1.06
# 174           1.80        0.75                  0.43             1.41
# 175           1.59        0.69                  0.43             1.35
# 176           1.65        0.68                  0.53             1.46
# 177           2.05        0.76                  0.56             1.35
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 173              7.7  0.64                          1.74      740
# 174              7.3  0.70                          1.56      750
# 175             10.2  0.59                          1.56      835
# 176              9.3  0.60                          1.62      840
# 177              9.2  0.61                          1.60      560

# %%
df.dtypes
# Out:
# Class                             int64
# Alcohol                         float64
# Malic acid                      float64
# Ash                             float64
# Alcalinity of ash               float64
# Magnesium                         int64
# Total phenols                   float64
# Flavanoids                      float64
# Nonflavanoid phenols            float64
# Proanthocyanins                 float64
# Color intensity                 float64
# Hue                             float64
# OD280/OD315 of diluted wines    float64
# Proline                           int64
# dtype: object

# %%
df['OD280/OD315 of diluted wines'].min()
# Out:
# 1.27

# %%
df['OD280/OD315 of diluted wines'].max()
# Out:
# 4.0

# %%
df['Class'].value_counts()
# Out:
# Class
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')

# %%
df.shape
# Out:
# (178, 14)

# %%
df.dtypes
# Out:
# Class                             int64
# Alcohol                         float64
# Malic acid                      float64
# Ash                             float64
# Alcalinity of ash               float64
# Magnesium                         int64
# Total phenols                   float64
# Flavanoids                      float64
# Nonflavanoid phenols            float64
# Proanthocyanins                 float64
# Color intensity                 float64
# Hue                             float64
# OD280/OD315 of diluted wines    float64
# Proline                           int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Class                           0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
x = df[['Alcohol','Alcalinity of ash',
       'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
       'Color intensity', 'Hue',
       'OD280/OD315 of diluted wines']]
y = df['Class']

# %%
from  sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x,)

# %%
x = pd.DataFrame(x)
x.head(5)
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.518613 -1.169593  1.913905  0.808997  1.034819 -0.659563  0.251717
# 1  0.246290 -2.490847  0.018145  0.568648  0.733629 -0.820719 -0.293321
# 2  0.196879 -0.268738  0.088358  0.808997  1.215533 -0.498407  0.269020
# 3  1.691550 -0.809251  0.930918  2.491446  1.466525 -0.981875  1.186068
# 4  0.295700  0.451946  1.281985  0.808997  0.663351  0.226796 -0.319276
#
#           7         8
# 0  0.362177  1.847920
# 1  0.406051  1.113449
# 2  0.318304  0.788587
# 3 -0.427544  1.184071
# 4  0.362177  0.449601

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)*100
# Out:
# 94.44444444444444

# %%
import joblib 

joblib.dump(model, 'model.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']
